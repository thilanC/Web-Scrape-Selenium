# %%
import requests
from bs4 import BeautifulSoup


def scrape_text_from_url(url):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        text = ''
        for paragraph in soup.find_all('p'):
            text += paragraph.get_text() + '\n'

        return text
    else:
        print("Failed to retrieve content from URL:", url)
        return None

# %%
url = 'https://www.uptodate.com/contents/allergen-extracts-composition-manufacture-and-labeling/print' 
text = scrape_text_from_url(url)
if text:
    print(text)

# %%
import requests 
from bs4 import BeautifulSoup 


r = requests.get(url) 

print(r) 

soup = BeautifulSoup(r.content, 'html.parser') 
print(soup.prettify())
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html class="no-js" data-ng-app="utdApp" data-ng-class="[configCtrl2.fixedHTML(),{wkProspect:configCtrl2.isProspectView()}]" data-ng-controller="ConfigController as configCtrl2" lang="{{configCtrl2.defaultPageLang()}}">
#  <head>
#   <title>
#    UpToDate
#   </title>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="UpToDate" name="apple-mobile-web-app-title"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="/app/assets/utd-icon.png" rel="apple-touch-icon"/>
#   <meta content="!" name="fragment"/>
#   <link ng-href="{{configCtrl2.canonicalUrl()}}" rel="canonical"/>
#   <meta content="{{configCtrl2.metaDescription()}}" name="description"/>
#   <meta charset="utf-8"/>
#   <style type="text/css">
#    #appContainer {
#                 position: absolute;
#                 top: 0;
#                 right: 0;
#                 bottom: 0;
#                 left: 0;
#                 background: url(/app/assets/utd-menu/utd-icon.png) no-repeat;
#                 background-attachment: fixed;
#                 background-position: center;
#                 background-size: 48px 48px;
#             }
#   </style>
#   <!-- for prerender.io -->
#   <script>
#    window.prerenderReady = false;
#   </script>
#   <script type="text/javascript">
#    function OptanonWrapper() {
#                 window.utd_OneTrustInitialized = true;
#             }
#   </script>
#   <link href="/app/utd-all-9b5038baa4c8045fe3c7-1.css" rel="stylesheet"/>
#   <link href="/app/utd-all-9b5038baa4c8045fe3c7-2.css" rel="stylesheet"/>
#   <link href="/app/utd-all-9b5038baa4c8045fe3c7-3.css" rel="stylesheet"/>
#   <link href="/app/utd-all-9b5038baa4c8045fe3c7-4.css" rel="stylesheet"/>
#   <script src="/app/dist/pace-5e409afd478709c35fff.min.js">
#   </script>
#   <script src="/app/dist/polyfills-3b0cdc14614c43611f32.min.js">
#   </script>
#   <style ng-bind="configCtrl2.additiveContentCss()" ng-if="configCtrl2.additiveContentCss()">
#   </style>
#   <base href="/index.html"/>
#  </head>
#  <body class="ngLoading ds1-utd-js" data-ng-class="[configCtrl.browser.name,
#                           configCtrl.browser.type,
#                           configCtrl.browser.customVersion,
#                           configCtrl.browser.os,
#                           configCtrl.language(),
#                           configCtrl.getTextSize(),
#                           configCtrl.noHeaderClass(),
#                           configCtrl.fullscreenClass(),
#                           configCtrl.searchBarAutoComplete(),
#                           configCtrl.utdLogoFilename(),
#                           configCtrl.vueLoaded(),
#                           configCtrl.routeNameClass(),
#                           {topicView: configCtrl.isTopicView()},
#                           {myUtdView: configCtrl.isMyUtdView()},
#                           {isHomeSearchEmpty: configCtrl.isHomeSearchEmpty()},
#                           {isLandingHome: configCtrl.isLandingHome()},
#                           {topicPrint: configCtrl.isPrintView()},
#                           {gfxView: configCtrl.isGraphicView()},
#                           {graphicPrint: configCtrl.isPrintGraphic()},
#                           {fullWidth: configCtrl.fullTopicWidth()},
#                           {utdWkHeader: configCtrl.isHeaderRedesign()},
#                           {utdWkTopic: configCtrl.topicRedesign()},
#                           {hasSessionData: configCtrl.hasSessionData()},
#                           {fixedToolbar: configCtrl.isFixedToolbar()},
#                           {hideNavBar: configCtrl.hideNavBar()},
#                           {lockOverflow: configCtrl.lockBodyScroll()},
#                           {iosBodyLockHide: configCtrl.iosBodyLockHide()},
#                           {mobileonDesktop: configCtrl.isMobileOnDesktop()},
#                           {fixedSidebar: configCtrl.isFixedSidebar()},
#                           {hiddenFooter: configCtrl.isFooterHidden()},
#                           {hasPromo: configCtrl.hasPromoBox()},
#                           {'anonymous-user': configCtrl.isAnonymousUser()}]" data-ng-controller="ConfigController as configCtrl" data-ng-strict-di="" tabindex="-1">
#   <noscript>
#    It seems to us that you have your JavaScript disabled on your browser. JavaScript is required in order for our site to behave correctly.  Please enable JavaScript to use our site.
#   </noscript>
#   <div id="appContainer" ng-class="configCtrl.hideMarketingBanner()">
#    <div class="defaultFocusHidden" tabindex="-1">
#    </div>
#    <prospect-header>
#    </prospect-header>
#    <authenticated-header ng-if="configCtrl.isHeaderRedesign()">
#    </authenticated-header>
#    <div id="paceHolder">
#    </div>
#    <div class="utd-content-main" data-ng-class="configCtrl.mainClasses()" data-ui-view="" id="utd-main">
#    </div>
#    <mobile-prospect-footer ng-if="!configCtrl.isHeaderRedesign() &amp;&amp; configCtrl.isDesktopView()">
#    </mobile-prospect-footer>
#    <authenticated-footer ng-if="configCtrl.showWkFooter()">
#    </authenticated-footer>
#    <trial-subscribe>
#    </trial-subscribe>
#    <support-tag>
#    </support-tag>
#    <track-click-events>
#    </track-click-events>
#    <utd-spinner is-visible="configCtrl.isSpinnerVisible()">
#    </utd-spinner>
#   </div>
#   <!-- <div data-utd-modal-dialog></div> -->
#   <server-messaging>
#   </server-messaging>
#   <my-utd-dialog>
#   </my-utd-dialog>
#   <responsive-myuptodate>
#   </responsive-myuptodate>
#   <responsive-notifier>
#   </responsive-notifier>
#   <global-event-listener>
#   </global-event-listener>
#   <script src="/app/dist/angular-fb7fb23d3602b066f571.min.js">
#   </script>
#   <script src="/app/dist/vendors-eccdbd6d44df818fafe7.min.js">
#   </script>
#   <script src="/app/dist/iscroll-zoom.utd.js">
#   </script>
#   <script src="/app/dist/utd-all-9b5038baa4c8045fe3c7.min.js">
#   </script>
#   <script src="/app/dist/epic-39f90adf82ca4d0c52be.min.js">
#   </script>
#  </body>
# </html>

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" data-ng-app="utdApp" data-ng-class="[configCtrl2.fixedHTML(),{wkProspect:configCtrl2.isProspectView()}]" data-ng-controller="ConfigController as configCtrl2" lang="{{configCtrl2.defaultPageLang()}}">
# <head>
# <title>UpToDate</title>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="UpToDate" name="apple-mobile-web-app-title"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/app/assets/utd-icon.png" rel="apple-touch-icon"/>
# <meta content="!" name="fragment"/>
# <link ng-href="{{configCtrl2.canonicalUrl()}}" rel="canonical"/>
# <meta content="{{configCtrl2.metaDescription()}}" name="description"/>
# <meta charset="utf-8"/>
# <style type="text/css">
#             #appContainer {
#                 position: absolute;
#                 top: 0;
#                 right: 0;
#                 bottom: 0;
#                 left: 0;
#                 background: url(/app/assets/utd-menu/utd-icon.png) no-repeat;
#                 background-attachment: fixed;
#                 background-position: center;
#                 background-size: 48px 48px;
#             }
#         </style>
# <!-- for prerender.io -->
# <script> window.prerenderReady = false; </script>
# <script type="text/javascript">
#             function OptanonWrapper() {
#                 window.utd_OneTrustInitialized = true;
#             }
#         </script>
# <link href="/app/utd-all-9b5038baa4c8045fe3c7-1.css" rel="stylesheet"/>
# <link href="/app/utd-all-9b5038baa4c8045fe3c7-2.css" rel="stylesheet"/>
# <link href="/app/utd-all-9b5038baa4c8045fe3c7-3.css" rel="stylesheet"/>
# <link href="/app/utd-all-9b5038baa4c8045fe3c7-4.css" rel="stylesheet"/>
# <script src="/app/dist/pace-5e409afd478709c35fff.min.js"></script>
# <script src="/app/dist/polyfills-3b0cdc14614c43611f32.min.js"></script>
# <style ng-bind="configCtrl2.additiveContentCss()" ng-if="configCtrl2.additiveContentCss()"></style>
# <base href="/index.html"/>
# </head>
# <body class="ngLoading ds1-utd-js" data-ng-class="[configCtrl.browser.name,
#                           configCtrl.browser.type,
#                           configCtrl.browser.customVersion,
#                           configCtrl.browser.os,
#                           configCtrl.language(),
#                           configCtrl.getTextSize(),
#                           configCtrl.noHeaderClass(),
#                           configCtrl.fullscreenClass(),
#                           configCtrl.searchBarAutoComplete(),
#                           configCtrl.utdLogoFilename(),
#                           configCtrl.vueLoaded(),
#                           configCtrl.routeNameClass(),
#                           {topicView: configCtrl.isTopicView()},
#                           {myUtdView: configCtrl.isMyUtdView()},
#                           {isHomeSearchEmpty: configCtrl.isHomeSearchEmpty()},
#                           {isLandingHome: configCtrl.isLandingHome()},
#                           {topicPrint: configCtrl.isPrintView()},
#                           {gfxView: configCtrl.isGraphicView()},
#                           {graphicPrint: configCtrl.isPrintGraphic()},
#                           {fullWidth: configCtrl.fullTopicWidth()},
#                           {utdWkHeader: configCtrl.isHeaderRedesign()},
#                           {utdWkTopic: configCtrl.topicRedesign()},
#                           {hasSessionData: configCtrl.hasSessionData()},
#                           {fixedToolbar: configCtrl.isFixedToolbar()},
#                           {hideNavBar: configCtrl.hideNavBar()},
#                           {lockOverflow: configCtrl.lockBodyScroll()},
#                           {iosBodyLockHide: configCtrl.iosBodyLockHide()},
#                           {mobileonDesktop: configCtrl.isMobileOnDesktop()},
#                           {fixedSidebar: configCtrl.isFixedSidebar()},
#                           {hiddenFooter: configCtrl.isFooterHidden()},
#                           {hasPromo: configCtrl.hasPromoBox()},
#                           {'anonymous-user': configCtrl.isAnonymousUser()}]" data-ng-controller="ConfigController as configCtrl" data-ng-strict-di="" tabindex="-1">
# <noscript>It seems to us that you have your JavaScript disabled on your browser. JavaScript is required in order for our site to behave correctly.  Please enable JavaScript to use our site.</noscript>
# <div id="appContainer" ng-class="configCtrl.hideMarketingBanner()">
# <div class="defaultFocusHidden" tabindex="-1"></div>
# <prospect-header></prospect-header>
# <authenticated-header ng-if="configCtrl.isHeaderRedesign()"></authenticated-header>
# <div id="paceHolder"></div>
# <div class="utd-content-main" data-ng-class="configCtrl.mainClasses()" data-ui-view="" id="utd-main"></div>
# <mobile-prospect-footer ng-if="!configCtrl.isHeaderRedesign() &amp;&amp; configCtrl.isDesktopView()"></mobile-prospect-footer>
# <authenticated-footer ng-if="configCtrl.showWkFooter()"></authenticated-footer>
# <trial-subscribe></trial-subscribe>
# <support-tag></support-tag>
# <track-click-events></track-click-events>
# <utd-spinner is-visible="configCtrl.isSpinnerVisible()"></utd-spinner>
# </div>
# <!-- <div data-utd-modal-dialog></div> -->
# <server-messaging></server-messaging>
# <my-utd-dialog></my-utd-dialog>
# <responsive-myuptodate></responsive-myuptodate>
# <responsive-notifier></responsive-notifier>
# <global-event-listener></global-event-listener>
# <script src="/app/dist/angular-fb7fb23d3602b066f571.min.js"></script>
# <script src="/app/dist/vendors-eccdbd6d44df818fafe7.min.js"></script>
# <script src="/app/dist/iscroll-zoom.utd.js"></script>
# <script src="/app/dist/utd-all-9b5038baa4c8045fe3c7.min.js"></script>
# <script src="/app/dist/epic-39f90adf82ca4d0c52be.min.js"></script>
# </body>
# </html>

# %%
import requests 
from bs4 import BeautifulSoup 


r = requests.get(url) 

soup = BeautifulSoup(r.content, 'html.parser') 

s = soup.find('div', class_="utd-content-main") 
content = s.find_all('p') 

print(content)
# Out:
# []
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
